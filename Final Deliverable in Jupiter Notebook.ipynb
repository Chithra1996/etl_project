# %% [markdown]
# # Import What we need

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st

# %%
filename = pd.read_csv('Resources/bachelorette.csv')
 
filename2 = pd.read_csv('Resources/historical_bachelor_contestants.csv')

# %%
filename.head()
# Out:
#            SHOW  SEASON  CONTESTANT ELIMINATION-1 ELIMINATION-2 ELIMINATION-3  \
# 0          SHOW  SEASON          ID             1             2             3
# 1  Bachelorette      13  13_BRYAN_A            R1           NaN           NaN
# 2  Bachelorette      13  13_PETER_K           NaN             R           NaN
# 3  Bachelorette      13   13_ERIC_B           NaN           NaN             R
# 4  Bachelorette      13   13_DEAN_U           NaN             R           NaN
#
#   ELIMINATION-4 ELIMINATION-5 ELIMINATION-6 ELIMINATION-7  ... DATES-1  \
# 0             4             5             6             7  ...       1
# 1             R             R           NaN             R  ...     NaN
# 2           NaN           NaN             R             R  ...     NaN
# 3           NaN           NaN             R             R  ...     NaN
# 4             R           NaN           NaN             R  ...     NaN
#
# ...

# %%
filename2.head()
#if filename2['Season'] < "10":
   # filename2['Season'] = number_str.zfill(1)
    #filname2["Season"] = "0"+filename2["Season"].astype(str)
   # filename2['contestant id'] = filename2['id2'].astype(str)+ '_'+filename2['first letter']
# Out:
#    Unnamed: 0   Age Eliminated              Hometown            Name  \
# 0           0  23.0     Winner       Chanute, Kansas    Amanda Marsh
# 1           1  29.0  Runner-Up        Miami, Florida     Trista Rehn
# 2           2  24.0     Week 5         Dallas, Texas  Shannon Oliver
# 3           3  24.0     Week 4        Tempe, Arizona             Kim
# 4           4  22.0     Week 3  Terra Haute, Indiana    Cathy Grimes
#
#                         Occupation Outcome  Season
# 0                    Event Planner     NaN       1
# 1                Miami Heat Dancer     NaN       1
# 2  Financial Management Consultant     NaN       1
# 3                            Nanny     NaN       1
# 4                 Graduate Student     NaN       1

# %%
filename2.assign(id= "")
# Out:
#      Unnamed: 0   Age Eliminated                    Hometown  \
# 0             0  23.0     Winner             Chanute, Kansas
# 1             1  29.0  Runner-Up              Miami, Florida
# 2             2  24.0     Week 5               Dallas, Texas
# 3             3  24.0     Week 4              Tempe, Arizona
# 4             4  22.0     Week 3        Terra Haute, Indiana
# ..          ...   ...        ...                         ...
# 474          26  28.0        NaN                Plano, Texas
# 475          27  26.0        NaN  West Hollywood, California
# 476          28  26.0        NaN               Dallas, Texas
# 477          29  24.0        NaN               Austin, Texas
# 478          30  25.0        NaN      Castle Pines, Colorado
#
#                      Name                       Occupation Outcome  Season id
# 0            Amanda Marsh                    Event Planner     NaN       1
# 1             Trista Rehn                Miami Heat Dancer     NaN       1
# ...

# %% [markdown]
# # Concatenating season with name to create a primary/foreign key

# %%
filename2['id2'] = filename2['Season'].astype(str)+ '_'+ filename2['Name']
filename2
# Out:
#      Unnamed: 0   Age Eliminated                    Hometown  \
# 0             0  23.0     Winner             Chanute, Kansas
# 1             1  29.0  Runner-Up              Miami, Florida
# 2             2  24.0     Week 5               Dallas, Texas
# 3             3  24.0     Week 4              Tempe, Arizona
# 4             4  22.0     Week 3        Terra Haute, Indiana
# ..          ...   ...        ...                         ...
# 474          26  28.0        NaN                Plano, Texas
# 475          27  26.0        NaN  West Hollywood, California
# 476          28  26.0        NaN               Dallas, Texas
# 477          29  24.0        NaN               Austin, Texas
# 478          30  25.0        NaN      Castle Pines, Colorado
#
#                      Name                       Occupation Outcome  Season  \
# 0            Amanda Marsh                    Event Planner     NaN       1
# 1             Trista Rehn                Miami Heat Dancer     NaN       1
# ...

# %% [markdown]
# # Make the key all Upper Case

# %%
filename2['id2'] = filename2['id2'].str.upper()
filename2
# Out:
#      Unnamed: 0   Age Eliminated                    Hometown  \
# 0             0  23.0     Winner             Chanute, Kansas
# 1             1  29.0  Runner-Up              Miami, Florida
# 2             2  24.0     Week 5               Dallas, Texas
# 3             3  24.0     Week 4              Tempe, Arizona
# 4             4  22.0     Week 3        Terra Haute, Indiana
# ..          ...   ...        ...                         ...
# 474          26  28.0        NaN                Plano, Texas
# 475          27  26.0        NaN  West Hollywood, California
# 476          28  26.0        NaN               Dallas, Texas
# 477          29  24.0        NaN               Austin, Texas
# 478          30  25.0        NaN      Castle Pines, Colorado
#
#                      Name                       Occupation Outcome  Season  \
# 0            Amanda Marsh                    Event Planner     NaN       1
# 1             Trista Rehn                Miami Heat Dancer     NaN       1
# ...

# %% [markdown]
# # Seperate the id from last name to further make a primary key

# %%
filename2[['id2','last name']] = filename2['id2'].str.split(n = 1,expand=True)

# %% [markdown]
# # Replace the the last name that says none to X so we could make a primary key

# %%
filename2["last name"].replace({None: "X"}, inplace=True)

# %%
filename2.head(10)
# Out:
#    Unnamed: 0   Age Eliminated                   Hometown            Name  \
# 0           0  23.0     Winner            Chanute, Kansas    Amanda Marsh
# 1           1  29.0  Runner-Up             Miami, Florida     Trista Rehn
# 2           2  24.0     Week 5              Dallas, Texas  Shannon Oliver
# 3           3  24.0     Week 4             Tempe, Arizona             Kim
# 4           4  22.0     Week 3       Terra Haute, Indiana    Cathy Grimes
# 5           5  28.0     Week 3         Bonita, California       Christina
# 6           6  23.0     Week 3    Los Angeles, California   LaNease Adams
# 7           7  28.0     Week 3         Woodward, Oklahoma          Rhonda
# 8           8  27.0     Week 2  Beverly Hills, California           Alexa
# 9           9  28.0     Week 2         New York, New York             Amy
#
#                         Occupation Outcome  Season          id2 last name
# 0                    Event Planner     NaN       1     1_AMANDA     MARSH
# ...

# %% [markdown]
# # Took just the first letter of the last name so we could make a primary key

# %%
filename2['first letter'] = filename2['last name'].astype(str).str[0]
filename2
# Out:
#      Unnamed: 0   Age Eliminated                    Hometown  \
# 0             0  23.0     Winner             Chanute, Kansas
# 1             1  29.0  Runner-Up              Miami, Florida
# 2             2  24.0     Week 5               Dallas, Texas
# 3             3  24.0     Week 4              Tempe, Arizona
# 4             4  22.0     Week 3        Terra Haute, Indiana
# ..          ...   ...        ...                         ...
# 474          26  28.0        NaN                Plano, Texas
# 475          27  26.0        NaN  West Hollywood, California
# 476          28  26.0        NaN               Dallas, Texas
# 477          29  24.0        NaN               Austin, Texas
# 478          30  25.0        NaN      Castle Pines, Colorado
#
#                      Name                       Occupation Outcome  Season  \
# 0            Amanda Marsh                    Event Planner     NaN       1
# 1             Trista Rehn                Miami Heat Dancer     NaN       1
# ...

# %% [markdown]
# # Concatenate everything as a final key

# %%
#filename2['id2'] = filename2['Season'].astype(str)+ '_'+ filename2['Name']
filename2['contestant id'] = filename2['id2'].astype(str)+ '_'+filename2['first letter']
filename2
# Out:
#      Unnamed: 0   Age Eliminated                    Hometown  \
# 0             0  23.0     Winner             Chanute, Kansas
# 1             1  29.0  Runner-Up              Miami, Florida
# 2             2  24.0     Week 5               Dallas, Texas
# 3             3  24.0     Week 4              Tempe, Arizona
# 4             4  22.0     Week 3        Terra Haute, Indiana
# ..          ...   ...        ...                         ...
# 474          26  28.0        NaN                Plano, Texas
# 475          27  26.0        NaN  West Hollywood, California
# 476          28  26.0        NaN               Dallas, Texas
# 477          29  24.0        NaN               Austin, Texas
# 478          30  25.0        NaN      Castle Pines, Colorado
#
#                      Name                       Occupation Outcome  Season  \
# 0            Amanda Marsh                    Event Planner     NaN       1
# 1             Trista Rehn                Miami Heat Dancer     NaN       1
# ...

# %%
filename2["Age"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 474    False
# 475    False
# 476    False
# 477    False
# 478    False
# Name: Age, Length: 479, dtype: bool

# %%
filename.head()
# Out:
#            SHOW  SEASON  CONTESTANT ELIMINATION-1 ELIMINATION-2 ELIMINATION-3  \
# 0          SHOW  SEASON          ID             1             2             3
# 1  Bachelorette      13  13_BRYAN_A            R1           NaN           NaN
# 2  Bachelorette      13  13_PETER_K           NaN             R           NaN
# 3  Bachelorette      13   13_ERIC_B           NaN           NaN             R
# 4  Bachelorette      13   13_DEAN_U           NaN             R           NaN
#
#   ELIMINATION-4 ELIMINATION-5 ELIMINATION-6 ELIMINATION-7  ... DATES-1  \
# 0             4             5             6             7  ...       1
# 1             R             R           NaN             R  ...     NaN
# 2           NaN           NaN             R             R  ...     NaN
# 3           NaN           NaN             R             R  ...     NaN
# 4             R           NaN           NaN             R  ...     NaN
#
# ...

# %% [markdown]
# # Taking the first part of contestant id off because one sheet starts with 01 and the other sheet starts with 1

# %%
filename['conid'] = filename['CONTESTANT'].astype(str).str[2:]
filename.head()
# Out:
#            SHOW  SEASON  CONTESTANT ELIMINATION-1 ELIMINATION-2 ELIMINATION-3  \
# 0          SHOW  SEASON          ID             1             2             3
# 1  Bachelorette      13  13_BRYAN_A            R1           NaN           NaN
# 2  Bachelorette      13  13_PETER_K           NaN             R           NaN
# 3  Bachelorette      13   13_ERIC_B           NaN           NaN             R
# 4  Bachelorette      13   13_DEAN_U           NaN             R           NaN
#
#   ELIMINATION-4 ELIMINATION-5 ELIMINATION-6 ELIMINATION-7  ... DATES-2  \
# 0             4             5             6             7  ...       2
# 1             R             R           NaN             R  ...     NaN
# 2           NaN           NaN             R             R  ...      D1
# 3           NaN           NaN             R             R  ...     D10
# 4             R           NaN           NaN             R  ...      D8
#
# ...

# %% [markdown]
# # Made it so both keys had the same format ex. 01_firstname_lastinitial check conid2 at the end

# %%
filename['conid2'] = filename['SEASON'].astype(str)+filename['conid']
filename
# Out:
#              SHOW  SEASON     CONTESTANT ELIMINATION-1 ELIMINATION-2  \
# 0            SHOW  SEASON             ID             1             2
# 1    Bachelorette      13     13_BRYAN_A            R1           NaN
# 2    Bachelorette      13     13_PETER_K           NaN             R
# 3    Bachelorette      13      13_ERIC_B           NaN           NaN
# 4    Bachelorette      13      13_DEAN_U           NaN             R
# ..            ...     ...            ...           ...           ...
# 916      Bachelor       1  01_KRISTINA_X             E           NaN
# 917      Bachelor       1      01_LISA_X             E           NaN
# 918      Bachelor       1     01_PAULA_X             E           NaN
# 919      Bachelor       1    01_RACHEL_X             E           NaN
# 920      Bachelor       1     01_WENDI_X             E           NaN
#
#     ELIMINATION-3 ELIMINATION-4 ELIMINATION-5 ELIMINATION-6 ELIMINATION-7  \
# ...

# %% [markdown]
# # Drop unneeded duplicated columns

# %%
filename2.drop(columns = ['id2','Unnamed: 0','Outcome','last name','first letter'])
#Bang Bisuit
# Out:
#       Age Eliminated                    Hometown                  Name  \
# 0    23.0     Winner             Chanute, Kansas          Amanda Marsh
# 1    29.0  Runner-Up              Miami, Florida           Trista Rehn
# 2    24.0     Week 5               Dallas, Texas        Shannon Oliver
# 3    24.0     Week 4              Tempe, Arizona                   Kim
# 4    22.0     Week 3        Terra Haute, Indiana          Cathy Grimes
# ..    ...        ...                         ...                   ...
# 474  28.0        NaN                Plano, Texas           Erin Landry
# 475  26.0        NaN  West Hollywood, California  Adrianne "Jane" Aver
# 476  26.0        NaN               Dallas, Texas       Laura Pellerito
# 477  24.0        NaN               Austin, Texas          Revian Chang
# 478  25.0        NaN      Castle Pines, Colorado      Tahzjuan Hawkins
#
#                           Occupation  Season  contestant id
# ...

# %% [markdown]
# # Split hometown column into cities and state

# %%
# Deleting missing ou null data
filename2['Hometown'].dropna(inplace = True)

# %%
# split value columns
filename2_subset = filename2['Hometown'].str.split(",", n = 1, expand = True)

# %%
# Creating new city  column from filename2_subset
filename2["City"]= filename2_subset[0]

# %%
# Creating new state  column from filename2_subset
filename2["State"]= filename2_subset[1]

# %%
# Dropping old Hometown columns
filename2.drop(columns =["Hometown"], inplace = True)

# %% [markdown]
# # Converting files back into csv so we can load into Postgress

# %%
filename.to_csv('file_name.csv', index=False, encoding='utf-8')

# %%
filename2.to_csv('file_name2.csv', index=False, encoding='utf-8')

# %% [markdown]
# # Using SQL Alchemy to pull from postrgress

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
rds_connection_string = "postgres:postgres@localhost:5432/ETL Project"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# # Check for tables

# %%
engine.table_names()
# Out:
# ['contestant_details', 'show_outcomes']

# %%
contestant_details= engine.execute('select * from contestant_details').fetchall()
contestant_details
# Out:
# [(0, 23.0, 'Winner', 'Amanda Marsh', 'Event Planner', None, 1, '1_AMANDA', 'MARSH', 'M', '1_AMANDA_M', 'Chanute', ' Kansas'),
#  (1, 29.0, 'Runner-Up', 'Trista Rehn', 'Miami Heat Dancer', None, 1, '1_TRISTA', 'REHN', 'R', '1_TRISTA_R', 'Miami', ' Florida'),
#  (2, 24.0, 'Week 5', 'Shannon Oliver', 'Financial Management Consultant', None, 1, '1_SHANNON', 'OLIVER', 'O', '1_SHANNON_O', 'Dallas', ' Texas'),
#  (3, 24.0, 'Week 4', 'Kim', 'Nanny', None, 1, '1_KIM', 'X', 'X', '1_KIM_X', 'Tempe', ' Arizona'),
#  (4, 22.0, 'Week 3', 'Cathy Grimes', 'Graduate Student', None, 1, '1_CATHY', 'GRIMES', 'G', '1_CATHY_G', 'Terra Haute', ' Indiana'),
#  (5, 28.0, 'Week 3', 'Christina', 'Attorney', None, 1, '1_CHRISTINA', 'X', 'X', '1_CHRISTINA_X', 'Bonita', ' California'),
#  (6, 23.0, 'Week 3', 'LaNease Adams', 'Actress', None, 1, '1_LANEASE', 'ADAMS', 'A', '1_LANEASE_A', 'Los Angeles', ' California'),
# ...

# %%
show_outcomes = engine.execute('select *from show_outcomes').fetchall()
show_outcomes
# Out:
# [('Bachelorette', 13, '13_BRYAN_A', 'R1', None, None, 'R', 'R', None, 'R', None, None, 'W', None, None, 'D6', 'D13', 'D1', 'D7', 'D1', 'D1', 'D1', 'D1', '_BRYAN_A', '13_BRYAN_A'),
#  ('Bachelorette', 13, '13_PETER_K', None, 'R', None, None, None, 'R', 'R', None, None, 'E', None, 'D1', 'D6', 'D13', 'D9', 'D7', 'D1', 'D1', 'D1', 'D1', '_PETER_K', '13_PETER_K'),
#  ('Bachelorette', 13, '13_ERIC_B', None, None, 'R', None, None, 'R', 'R', None, 'E', None, None, 'D10', 'D8', 'D13', 'D9', 'D1', 'D3', 'D1', 'D1', None, '_ERIC_B', '13_ERIC_B'),
#  ('Bachelorette', 13, '13_DEAN_U', None, 'R', None, 'R', None, None, 'R', 'E', None, None, None, 'D8', 'D8', 'D1', 'D9', 'D7', 'D1', 'D1', None, None, '_DEAN_U', '13_DEAN_U'),
#  ('Bachelorette', 13, '13_ADAM_G', None, None, None, None, None, None, 'ED', None, None, None, None, 'D10', 'D8', 'D13', 'D9', 'D7', 'D3', None, None, None, '_ADAM_G', '13_ADAM_G'),
# ...

# %% [markdown]
# # Joined tables

# %%
joined_tables = engine.execute('select c.age,s.season from contestant_details c, show_outcomes s where c.contestant_id = s.conid2').fetchall()
joined_tables
# Out:
# [(23.0, 1),
#  (29.0, 1),
#  (24.0, 1),
#  (24.0, 1),
#  (22.0, 1),
#  (28.0, 1),
#  (23.0, 1),
#  (28.0, 1),
#  (27.0, 1),
#  (28.0, 1),
#  (25.0, 1),
#  (27.0, 1),
#  (23.0, 1),
#  (25.0, 1),
#  (27.0, 1),
#  (29.0, 1),
#  (30.0, 1),
#  (30.0, 1),
#  (22.0, 1),
#  (31.0, 1),
#  (27.0, 1),
#  (29.0, 1),
#  (24.0, 1),
#  (29.0, 1),
#  (26.0, 1),
#  (27.0, 2),
#  (22.0, 2),
#  (31.0, 2),
#  (27.0, 2),
#  (28.0, 2),
#  (30.0, 2),
#  (23.0, 2),
#  (24.0, 2),
#  (22.0, 2),
#  (26.0, 2),
#  (24.0, 2),
#  (25.0, 2),
#  (33.0, 2),
#  (30.0, 2),
#  (27.0, 2),
#  (26.0, 2),
#  (29.0, 2),
#  (29.0, 2),
#  (24.0, 2),
#  (24.0, 2),
#  (22.0, 2),
#  (30.0, 2),
#  (26.0, 2),
#  (22.0, 5),
#  (23.0, 5),
#  (26.0, 5),
#  (28.0, 5),
#  (23.0, 5),
#  (28.0, 5),
#  (25.0, 5),
#  (24.0, 5),
#  (22.0, 5),
#  (27.0, 5),
#  (27.0, 5),
#  (25.0, 5),
#  (25.0, 5),
#  (24.0, 5),
#  (24.0, 5),
#  (26.0, 5),
#  (25.0, 5),
#  (25.0, 5),
#  (21.0, 5),
#  (26.0, 5),
#  (26.0, 5),
#  (25.0, 5),
#  (24.0, 9),
# ...

# %%
engine.execute
# Out:
# <bound method Engine.execute of Engine(postgresql://postgres:***@localhost:5432/ETL Project)>
