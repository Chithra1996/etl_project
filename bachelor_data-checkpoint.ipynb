# %%
# Dependencies
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st

# %%
pwd
# Out:
# 'C:\\Users\\grace\\Desktop\\Project\\The Bachelor'

# %%
filename = ("Bachelor-contestants.csv")

# %%
df = pd.read_csv(filename)

# %%
df.head()
# Out:
#    Season            Name   Age                      Hometown State  \
# 0    15.0       Jed Wyatt  25.0        Sevierville, Tennessee    TN
# 1    15.0   Tyler Cameron  26.0              Jupiter, Florida    FL
# 2    15.0     Peter Weber  27.0  Westlake Village, California    CA
# 3    15.0     Luke Parker  24.0          Gainesville, Georgia    GA
# 4    15.0  Garrett Powell  27.0             Homewood, Alabama    AL
#
#                         College             Occupation  Win_Loss  Height (cm)  \
# 0            Belmont University       Singer/Sonwriter       1.0       190.50
# 1                   Wake Forest     General Contractor       0.0       187.96
# 2             Baylor University                  Pilot       0.0       175.25
# 3           Faulkner University  Import/Export Manager       0.0       175.00
# 4  Mississippi State University               Golf Pro       0.0          NaN
#
#   Girlfriend While on the Show? Hair Color Eye Color
# ...

# %%
filename_2 = ("bachelorette-contestants.csv")

# %%
bachelorette_contestants_df = pd.read_csv(filename_2)

# %%
bachelorette_contestants_df.head()
# Out:
#              Name   Age                       Occupation  \
# 0    Amanda Marsh  23.0                    Event Planner
# 1     Trista Rehn  29.0                Miami Heat Dancer
# 2  Shannon Oliver  24.0  Financial Management Consultant
# 3             Kim  24.0                            Nanny
# 4    Cathy Grimes  22.0                 Graduate Student
#
#                Hometown  Height  ElimWeek  Season
# 0       Chanute, Kansas     NaN       NaN       1
# 1        Miami, Florida     NaN       6.0       1
# 2         Dallas, Texas     NaN       5.0       1
# 3        Tempe, Arizona     NaN       4.0       1
# 4  Terra Haute, Indiana     NaN       3.0       1

# %%
filename_3 = ("Bachelor-elimination.csv")

# %%
Bachelor_elimination_df = pd.read_csv(filename_3)

# %%
Bachelor_elimination_df.head()
# Out:
#            SHOW  SEASON  CONTESTANT ELIMINATION-1 ELIMINATION-2 ELIMINATION-3  \
# 0          SHOW  SEASON          ID             1             2             3
# 1  Bachelorette      13  13_BRYAN_A            R1           NaN           NaN
# 2  Bachelorette      13  13_PETER_K           NaN             R           NaN
# 3  Bachelorette      13   13_ERIC_B           NaN           NaN             R
# 4  Bachelorette      13   13_DEAN_U           NaN             R           NaN
#
#   ELIMINATION-4 ELIMINATION-5 ELIMINATION-6 ELIMINATION-7  ... DATES-1  \
# 0             4             5             6             7  ...       1
# 1             R             R           NaN             R  ...     NaN
# 2           NaN           NaN             R             R  ...     NaN
# 3           NaN           NaN             R             R  ...     NaN
# 4             R           NaN           NaN             R  ...     NaN
#
# ...

# %%
with open ("bachelor_data.ipynb") as f:
    data = json.load(f)

# %%
data
# Out:
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {},
#    'outputs': [],
#    'source': ['# Dependencies\n',
#     'import requests\n',
#     'import json\n',
#     'import pandas as pd\n',
#     'import matplotlib.pyplot as plt\n',
#     'from scipy.stats import linregress\n',
#     'import numpy as np\n',
#     'import c\n',
#     'import scipy.stats as st']},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {},
#    'outputs': [{'data': {'text/plain': ["'C:\\\\Users\\\\grace\\\\Desktop\\\\Project\\\\The Bachelor'"]},
#      'execution_count': 2,
#      'metadata': {},
#      'output_type': 'execute_result'}],
#    'source': ['pwd']},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {},
#    'outputs': [],
#    'source': ['filename = ("Bachelor-contestants.csv")']},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {},
#    'outputs': [],
#    'source': ['df = pd.read_csv(filename)']},
# ...
